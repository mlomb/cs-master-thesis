# %%
import pandas as pd

# %%
df = pd.read_csv("/mnt/d/datasets/puzzles/lichess_db_puzzle.csv")
df.Themes = df.Themes.str.split(" ").apply(lambda x: frozenset(x))

# %%
df
# Out:
#         PuzzleId                                                FEN  \
# 0          00008  r6k/pp2r2p/4Rp1Q/3p4/8/1N1P2R1/PqP2bPP/7K b - ...
# 1          0000D  5rk1/1p3ppp/pq3b2/8/8/1P1Q1N2/P4PPP/3R2K1 w - ...
# 2          0008Q       8/4R3/1p2P3/p4r2/P6p/1P3Pk1/4K3/8 w - - 1 64
# 3          0009B  r2qr1k1/b1p2ppp/pp4n1/P1P1p3/4P1n1/B2P2Pb/3NBP...
# 4          000Vc             8/8/4k1p1/2KpP2p/5PP1/8/8/8 w - - 0 53
# ...          ...                                                ...
# 3764374    zzzc4   3r3k/p5pp/8/5R2/1BQ1p3/P3q3/Bb4PP/6K1 w - - 0 28
# 3764375    zzzco  5Q2/pp3R1P/1kpp4/4p3/2P1P3/3PP2P/Pr2q3/2K5 w -...
# 3764376    zzzhI  r3kb1r/ppp2ppp/2n5/3q3b/3P1B2/5N1P/PPP3P1/RN1Q...
# 3764377    zzzhg  r2q1rk1/4bppp/p1n1pn2/1p1pN3/2pP2b1/1PP1P3/PBQ...
# 3764378    zzzw8           8/p7/2Kn4/4k1p1/6Pp/2PB3P/8/8 b - - 3 42
#
#                                  Moves  Rating  RatingDeviation  Popularity  \
# ...

# %%
from itertools import chain
unique_lists_in_items = df.Themes.unique().tolist()
set_of_items = set(chain(*unique_lists_in_items))
set_of_items
# Out:
# {'advancedPawn',
#  'advantage',
#  'anastasiaMate',
#  'arabianMate',
#  'attackingF2F7',
#  'attraction',
#  'backRankMate',
#  'bishopEndgame',
#  'bodenMate',
#  'capturingDefender',
#  'castling',
#  'clearance',
#  'crushing',
#  'defensiveMove',
#  'deflection',
#  'discoveredAttack',
#  'doubleBishopMate',
#  'doubleCheck',
#  'dovetailMate',
#  'enPassant',
#  'endgame',
#  'equality',
#  'exposedKing',
#  'fork',
#  'hangingPiece',
#  'hookMate',
#  'interference',
#  'intermezzo',
#  'kingsideAttack',
#  'knightEndgame',
#  'long',
#  'master',
#  'masterVsMaster',
#  'mate',
#  'mateIn1',
#  'mateIn2',
#  'mateIn3',
#  'mateIn4',
#  'mateIn5',
#  'middlegame',
#  'oneMove',
#  'opening',
#  'pawnEndgame',
#  'pin',
#  'promotion',
#  'queenEndgame',
#  'queenRookEndgame',
#  'queensideAttack',
#  'quietMove',
#  'rookEndgame',
#  'sacrifice',
#  'short',
#  'skewer',
#  'smotheredMate',
#  'superGM',
#  'trappedPiece',
#  'underPromotion',
#  'veryLong',
#  'xRayAttack',
# ...

# %%
sub_df = df.sample(15_000)
sub_df = sub_df[["FEN", "Moves", "Rating"]]
sub_df.to_csv("puzzles.csv", index=False, header=False)
sub_df
# Out:
#                                                        FEN  \
# 1184891  3r2k1/pp2q1bN/7n/5p1Q/4pB2/8/PPP3P1/2K1R3 w - ...
# 692834   1r3b1k/pp3B1p/2b2N1p/4p1r1/4P1P1/P4P1P/1P6/R4R...
# 2980508  2r1k1B1/R7/3B1p2/8/P7/2pb3P/3r1PP1/6K1 b - - 6 35
# 1257530  r1b2rk1/pp3pp1/2n2B1p/3qp3/8/PNPB4/2P2PPP/R2QK...
# 190827   r2q1r1k/ppp3pp/3pBbn1/3Pn3/8/2N1Q3/PP3PPP/R1BR...
# ...                                                    ...
# 3528913  r1b2r1k/pp2Qpp1/n1p2N1p/q7/7P/2p2NP1/Pb2PPB1/3...
# 272972   3r2k1/pp3pp1/2p2b1p/4B3/r1qPQ3/2P5/1P4PP/4RRK1...
# 2508736  5rk1/4Rrpp/8/3p4/Q1pP1p2/P1q2P2/6PP/4R1K1 w - ...
# 2791843  r3kb1r/p2n1ppp/Q3p3/1p1p2B1/3n4/5N2/Pq1N1PPP/R...
# 361641   4r1k1/pp3ppp/3q4/3pr3/4P3/1P1Q3P/P3RPP1/3R2K1 ...
#
#                                  Moves  Rating
# 1184891            f4h6 g7b2 c1b2 e7b4    2293
# 692834   g1g2 h8g7 h3h4 g7f6 h4g5 f6f7    1905
# 2980508            c3c2 g8f7 e8d8 d6e7    1587
# 1257530            g7f6 d3h7 g8h7 d1d5    1488
# ...

# %%
df = df[df["Rating"] < 3000]
df["Bucket"] = df["Rating"] // 100

sub_df = df.groupby("Bucket").sample(100)
sub_df = sub_df[["FEN", "Moves", "Rating"]]
sub_df.to_csv("puzzles.csv", index=False, header=False)
